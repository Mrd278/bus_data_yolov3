# %% [markdown]
# <a href="https://colab.research.google.com/github/Mrd278/bus_data_yolov3/blob/master/train_bus_data_yolov3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/AlexeyAB/darknet.git
# Out:
# fatal: destination path 'darknet' already exists and is not an empty directory.

# %%
cd /content/darknet
# Out:
# /content/darknet

# %%
# !ls
# Out:
# 3rdparty		darknet_video.py       obj.names
# appveyor.yml		data		       README.md
# backup			dataset		       results
# build			images		       scripts
# build.ps1		image_yolov2.sh        src
# build.sh		image_yolov3.sh        test.txt
# bus_data_yolov3		include		       train.txt
# cfg			json_mjpeg_streams.sh  video_v2.sh
# cmake			LICENSE		       video_yolov3.sh
# CMakeLists.txt		Makefile	       yolov3-tiny.conv.15
# darknet			net_cam_v3.sh	       yolov3-tiny-obj.cfg
# DarknetConfig.cmake.in	obj
# darknet.py		obj.data

# %%
# !make
# Out:
# chmod +x *.sh
# g++ -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:909:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# g++ -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -DCUDNN_HALF -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -DCUDNN_HALF -c ./src/http_stream.cpp -o obj/http_stream.o
# ...

# %%
# !ls
# Out:
# 3rdparty		darknet_video.py       obj.names
# appveyor.yml		data		       README.md
# backup			dataset		       results
# build			images		       scripts
# build.ps1		image_yolov2.sh        src
# build.sh		image_yolov3.sh        test.txt
# bus_data_yolov3		include		       train.txt
# cfg			json_mjpeg_streams.sh  video_v2.sh
# cmake			LICENSE		       video_yolov3.sh
# CMakeLists.txt		Makefile	       yolov3-tiny.conv.15
# darknet			net_cam_v3.sh	       yolov3-tiny-obj.cfg
# DarknetConfig.cmake.in	obj
# darknet.py		obj.data

# %%
! ./darknet
# Out:
# usage: ./darknet <function>

# %%
! git clone https://github.com/Mrd278/bus_data_yolov3.git
# Out:
# fatal: destination path 'bus_data_yolov3' already exists and is not an empty directory.

# %%
mv /content/darknet/bus_data_yolov3/images/ /content/darknet/
# Out:
# mv: cannot stat '/content/darknet/bus_data_yolov3/images/': No such file or directory

# %%
mv /content/darknet/bus_data_yolov3/dataset/ /content/darknet/

# %%
! ./darknet detector train cfg/obj.data cfg/yolov3-tiny-obj.cfg yolov3-tiny.conv.15 -dont_show 0
# Out:
#  CUDA-version: 10000 (10010)
# ...
# , cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  OpenCV version: 3.2.0
# yolov3-tiny-obj
#  compute_capability = 750, cudnn_half = 1
# net.optimized_memory = 0
# batch = 32, time_steps = 1, train = 1
#    layer   filters  size/strd(dil)      input                output
#    0 conv     16       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  16 0.150 BF
#    1 max                2x 2/ 2    416 x 416 x  16 ->  208 x 208 x  16 0.003 BF
#    2 conv     32       3 x 3/ 1    208 x 208 x  16 ->  208 x 208 x  32 0.399 BF
#    3 max                2x 2/ 2    208 x 208 x  32 ->  104 x 104 x  32 0.001 BF
#    4 conv     64       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  64 0.399 BF
#    5 max                2x 2/ 2    104 x 104 x  64 ->   52 x  52 x  64 0.001 BF
#    6 conv    128       3 x 3/ 1     52 x  52 x  64 ->   52 x  52 x 128 0.399 BF
#    7 max                2x 2/ 2     52 x  52 x 128 ->   26 x  26 x 128 0.000 BF
# ...

# %%
cd /content/darknet/
# Out:
# /content/darknet

# %%
# !ls
# Out:
# 3rdparty		   darknet		   net_cam_v3.sh
# appveyor.yml		   DarknetConfig.cmake.in  obj
# backup			   darknet.py		   README.md
# bad.list		   darknet_video.py	   results
# build			   data			   scripts
# build.ps1		   dataset		   src
# build.sh		   images		   test.txt
# bus_data_yolov3		   image_yolov2.sh	   train.txt
# cfg			   image_yolov3.sh	   video_v2.sh
# chart.png		   include		   video_yolov3.sh
# chart_yolov3-tiny-obj.png  json_mjpeg_streams.sh   yolov3-tiny.conv.15
# cmake			   LICENSE
# CMakeLists.txt		   Makefile

# %%
! ./darknet detector test cfg/obj.data cfg/yolov3-tiny-obj.cfg backup/yolov3-tiny-obj_2000.weights images/obj/000058.jpg
# Out:
#  CUDA-version: 10000 (10010)
# ...
# , cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  OpenCV version: 3.2.0
#  compute_capability = 750, cudnn_half = 1
# net.optimized_memory = 0
# batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     16       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  16 0.150 BF
#    1 max                2x 2/ 2    416 x 416 x  16 ->  208 x 208 x  16 0.003 BF
#    2 conv     32       3 x 3/ 1    208 x 208 x  16 ->  208 x 208 x  32 0.399 BF
#    3 max                2x 2/ 2    208 x 208 x  32 ->  104 x 104 x  32 0.001 BF
#    4 conv     64       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  64 0.399 BF
#    5 max                2x 2/ 2    104 x 104 x  64 ->   52 x  52 x  64 0.001 BF
#    6 conv    128       3 x 3/ 1     52 x  52 x  64 ->   52 x  52 x 128 0.399 BF
#    7 max                2x 2/ 2     52 x  52 x 128 ->   26 x  26 x 128 0.000 BF
# ...

# %%
from google.colab.patches import cv2_imshow

# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.imread('predictions.jpg')
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

# %%
! ./darknet detector test cfg/obj.data cfg/yolov3-tiny-obj.cfg backup/yolov3-tiny-obj_2000.weights images/obj/000028.jpg
# Out:
#  CUDA-version: 10000 (10010)
# ...
# , cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  OpenCV version: 3.2.0
#  compute_capability = 750, cudnn_half = 1
# net.optimized_memory = 0
# batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     16       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  16 0.150 BF
#    1 max                2x 2/ 2    416 x 416 x  16 ->  208 x 208 x  16 0.003 BF
#    2 conv     32       3 x 3/ 1    208 x 208 x  16 ->  208 x 208 x  32 0.399 BF
#    3 max                2x 2/ 2    208 x 208 x  32 ->  104 x 104 x  32 0.001 BF
#    4 conv     64       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  64 0.399 BF
#    5 max                2x 2/ 2    104 x 104 x  64 ->   52 x  52 x  64 0.001 BF
#    6 conv    128       3 x 3/ 1     52 x  52 x  64 ->   52 x  52 x 128 0.399 BF
#    7 max                2x 2/ 2     52 x  52 x 128 ->   26 x  26 x 128 0.000 BF
# ...

# %%
image = cv2.imread('predictions.jpg')
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

# %%
! ./darknet detector test cfg/obj.data cfg/yolov3-tiny-obj.cfg backup/yolov3-tiny-obj_2000.weights images/obj/000014.jpg
# Out:
#  CUDA-version: 10000 (10010)
# ...
# , cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  OpenCV version: 3.2.0
#  compute_capability = 750, cudnn_half = 1
# net.optimized_memory = 0
# batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     16       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  16 0.150 BF
#    1 max                2x 2/ 2    416 x 416 x  16 ->  208 x 208 x  16 0.003 BF
#    2 conv     32       3 x 3/ 1    208 x 208 x  16 ->  208 x 208 x  32 0.399 BF
#    3 max                2x 2/ 2    208 x 208 x  32 ->  104 x 104 x  32 0.001 BF
#    4 conv     64       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  64 0.399 BF
#    5 max                2x 2/ 2    104 x 104 x  64 ->   52 x  52 x  64 0.001 BF
#    6 conv    128       3 x 3/ 1     52 x  52 x  64 ->   52 x  52 x 128 0.399 BF
#    7 max                2x 2/ 2     52 x  52 x 128 ->   26 x  26 x 128 0.000 BF
# ...

# %%
image = cv2.imread('predictions.jpg')
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

# %%
! ./darknet detector test cfg/obj.data cfg/yolov3-tiny-obj.cfg backup/yolov3-tiny-obj_2000.weights test_bus.jpg
# Out:
#  CUDA-version: 10000 (10010)
# ...
# , cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  OpenCV version: 3.2.0
#  compute_capability = 750, cudnn_half = 1
# net.optimized_memory = 0
# batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     16       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  16 0.150 BF
#    1 max                2x 2/ 2    416 x 416 x  16 ->  208 x 208 x  16 0.003 BF
#    2 conv     32       3 x 3/ 1    208 x 208 x  16 ->  208 x 208 x  32 0.399 BF
#    3 max                2x 2/ 2    208 x 208 x  32 ->  104 x 104 x  32 0.001 BF
#    4 conv     64       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  64 0.399 BF
#    5 max                2x 2/ 2    104 x 104 x  64 ->   52 x  52 x  64 0.001 BF
#    6 conv    128       3 x 3/ 1     52 x  52 x  64 ->   52 x  52 x 128 0.399 BF
#    7 max                2x 2/ 2     52 x  52 x 128 ->   26 x  26 x 128 0.000 BF
# ...

# %%
image = cv2.imread('predictions.jpg')
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

# %%
! ./darknet detector test cfg/obj.data cfg/yolov3-tiny-obj.cfg backup/yolov3-tiny-obj_2000.weights test_bus_2.jpg
# Out:
#  CUDA-version: 10000 (10010)
# ...
# , cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  OpenCV version: 3.2.0
#  compute_capability = 750, cudnn_half = 1
# net.optimized_memory = 0
# batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     16       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  16 0.150 BF
#    1 max                2x 2/ 2    416 x 416 x  16 ->  208 x 208 x  16 0.003 BF
#    2 conv     32       3 x 3/ 1    208 x 208 x  16 ->  208 x 208 x  32 0.399 BF
#    3 max                2x 2/ 2    208 x 208 x  32 ->  104 x 104 x  32 0.001 BF
#    4 conv     64       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  64 0.399 BF
#    5 max                2x 2/ 2    104 x 104 x  64 ->   52 x  52 x  64 0.001 BF
#    6 conv    128       3 x 3/ 1     52 x  52 x  64 ->   52 x  52 x 128 0.399 BF
#    7 max                2x 2/ 2     52 x  52 x 128 ->   26 x  26 x 128 0.000 BF
# ...

# %%
image = cv2.imread('predictions.jpg')
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()
